# %% [markdown]
# ## RSS

# %% [markdown]
# You can find RSS feeds on many different sites. [Library of Congress](https://www.loc.gov/rss/) has a lot. Most blogs and news web sites have them, for example [Tech Crunch](https://techcrunch.com/rssfeeds/), [New York Times](http://www.nytimes.com/services/xml/rss/index.html), and [NPR](https://help.npr.org/customer/portal/articles/2094175-where-can-i-find-npr-rss-feeds-). The [DC Public Library](http://www.dclibrary.org/) even gives you an RSS feed of your [catalog searches](https://catalog.dclibrary.org/client/rss/hitlist/dcpl/qu=python).
#
# Today we are going to take a look at the [Netflix Top 100 DVDs](https://dvd.netflix.com/RSSFeeds). We will use the Python package [FeedParser](https://pypi.python.org/pypi/feedparser) to work with the RSS feed. FeedParser will allow us to deconstruct the data in the feed.

# %%
import feedparser
import pandas as pd

# %%
RSS_URL = "http://dvd.netflix.com/Top100RSS"

# %%
feed = feedparser.parse(RSS_URL)

# %%
type(feed)
# Out:
# feedparser.FeedParserDict

# %% [markdown]
# "parse" is the primary function in FeedParser. The returned object is dictionary like and can be handled similarly. For example, we can look at the keys it contains.

# %%
feed.feed.keys()
# Out:
# dict_keys(['title', 'subtitle_detail', 'ttl', 'link', 'subtitle', 'language', 'title_detail', 'links', 'cf_treatas'])

# %%
type(feed.bozo)
# Out:
# int

# %%
feed.keys()
# Out:
# dict_keys(['namespaces', 'version', 'entries', 'href', 'bozo', 'encoding', 'status', 'feed', 'headers'])

# %%
feed.version
# Out:
# 'rss20'

# %% [markdown]
# We will look at some, but not all, of the data stored in the feed. For more information about the keys, see the [documentation](http://pythonhosted.org/feedparser/).
#
# We can use the version to check which type of feed we have.

# %% [markdown]
# Bozo is an interesing key to know about if you are going to operationalize RSS feed ingestion. FeedParser sets the bozo bit when it detects a feed is not well-formed. (FeedParser will still parse the feed if it is not well-formed.)

# %%
if feed.bozo == 0:
    print("Well done, you have a well-formed feed!")
else:
    print("Potential trouble ahead.")
# Out:
# Well done, you have a well-formed feed!

# %% [markdown]
# We can look at some of the feed elements through the feed attribute.

# %%
print(feed.feed.title)
print(feed.feed.link)
print(feed.feed.description)
# Out:
# Netflix Top 100
# http://dvd.netflix.com
# Top 100 Netflix movies, published every 2 weeks.

# %% [markdown]
# Published date is another thing we can look at, but not all feeds use this.

# %%
feed.feed.published
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda/envs/wits/lib/python3.5/site-packages/feedparser.py in __getattr__(self, key)
#     398         try:
# --> 399             return self.__getitem__(key)
#     400         except KeyError:
#
# /Applications/anaconda/envs/wits/lib/python3.5/site-packages/feedparser.py in __getitem__(self, key)
#     356                 return dict.__getitem__(self, realkey)
# --> 357         return dict.__getitem__(self, key)
#     358
#
# KeyError: 'published'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0ac9e738a544> in <module>()
# ----> 1 feed.feed.published
#
# /Applications/anaconda/envs/wits/lib/python3.5/site-packages/feedparser.py in __getattr__(self, key)
#     399             return self.__getitem__(key)
#     400         except KeyError:
# --> 401             raise AttributeError("object has no attribute '%s'" % key)
#     402
#     403     def __hash__(self):
#
# AttributeError: object has no attribute 'published'

# %% [markdown]
# Like with dictionaries, we can use the "get" method to see if a key exists. This is useful if we are writing code.

# %%
feed.get('published', 'N/A')
# Out:
# 'N/A'

# %% [markdown]
# The items we are looking for are contained in the entries. Given the feed we are working with, how many entries do you think we have?

# %%
len(feed.entries)
# Out:
# 100

# %% [markdown]
# The items in entries are stored as a list.

# %%
feed.entries[0].title
# Out:
# 'Money Monster'

# %%
i = 0
for entry in feed.entries:
    print(i, feed.entries[i].title)
    i += 1
# Out:
# 0 Money Monster
# 1 Game of Thrones
# 2 Sully
# 3 Now You See Me 2
# 4 Ghostbusters
# 5 Star Trek Beyond
# 6 Captain America: Civil War
# 7 The Legend of Tarzan
# 8 The Jungle Book (2016)
# 9 Free State of Jones
# 10 The Nice Guys
# 11 The Magnificent Seven
# 12 Jason Bourne
# 13 Hell or High Water
# 14 Central Intelligence
# 15 Batman v Superman: Dawn of Justice
# 16 X-Men: Apocalypse
# 17 The Huntsman: Winter's War
# 18 Independence Day: Resurgence
# 19 Whiskey Tango Foxtrot
# 20 Suicide Squad
# 21 Bad Moms
# 22 Me Before You
# 23 Deepwater Horizon
# 24 A Hologram for the King
# 25 The Infiltrator
# 26 The Shallows
# 27 The Boss
# 28 Eye in the Sky
# 29 Outlander
# 30 Mother's Day
# 31 The Accountant
# 32 Homeland
# 33 The Secret Life of Pets
# 34 Criminal
# 35 Finding Dory
# 36 Mechanic: Resurrection
# 37 The Finest Hours
# 38 The Meddler
# 39 London Has Fallen
# 40 Florence Foster Jenkins
# 41 Joy
# 42 Inferno
# 43 Miracles from Heaven
# 44 The Man Who Knew Infinity
# 45 War Dogs
# 46 Hello, My Name Is Doris
# 47 The Revenant
# 48 Neighbors 2: Sorority Rising
# 49 My Big Fat Greek Wedding 2
# 50 13 Hours: The Secret Soldiers of Benghazi
# 51 Race
# 52 11/22/63
# 53 The Divergent Series: Allegiant
# 54 The Duel
# 55 Blood Father
# 56 Sausage Party
# 57 Love & Friendship
# 58 Bridge of Spies
# 59 House of Cards
# 60 10 Cloverfield Lane
# 61 Warcraft
# 62 Don't Breathe
# 63 Miss Peregrine's Home for Peculiar Children
# 64 Teenage Mutant Ninja Turtles: Out of the Shadows
# 65 I Am Wrath
# 66 Deadpool
# 67 Captain Fantastic
# 68 Ben-Hur (2016)
# 69 The Girl on the Train
# 70 Café Society
# 71 The Hateful Eight
# 72 Mike and Dave Need Wedding Dates
# 73 The BFG
# 74 Concussion
# 75 Hacksaw Ridge
# 76 Keanu
# 77 Hunt for the Wilderpeople
# 78 Genius
# 79 Wild Oats
# 80 Dark Horse
# 81 The Conjuring 2
# 82 The Night Manager
# 83 Brooklyn
# 84 Midnight Special
# 85 Hail, Caesar!
# 86 Manchester by the Sea
# 87 Pete's Dragon
# 88 The Intern
# 89 Star Wars: Episode VII: The Force Awakens
# 90 Eddie the Eagle
# 91 Snowden
# 92 In the Heart of the Sea
# 93 Alice Through the Looking Glass
# 94 Zootopia
# 95 Demolition
# 96 God's Not Dead 2
# 97 The Good Wife
# 98 Longmire
# 99 The Angry Birds Movie

# %% [markdown]
# Given that information, what is something we can do with this data? Why not make it a dataframe?

# %%
df = pd.DataFrame(feed.entries)

# %%
feed.entries[0]
# Out:
# {'guidislink': False,
#  'id': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#  'link': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#  'links': [{'href': 'https://dvd.netflix.com/Movie/Money-Monster/80084089',
#    'rel': 'alternate',
#    'type': 'text/html'}],
#  'summary': '<a href="https://dvd.netflix.com/Movie/Money-Monster/80084089"><img src="//secure.netflix.com/us/boxshots/small/80084089.jpg"/></a><br>Landing in dire financial straits after following a stock tip from bombastic TV persona Lee Gates, fuming Kyle Budwell takes the lout hostage on live television and threatens to kill him unless he turns the stock price around before the closing bell.',
#  'summary_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/html',
#   'value': '<a href="https://dvd.netflix.com/Movie/Money-Monster/80084089"><img src="//secure.netflix.com/us/boxshots/small/80084089.jpg"/></a><br>Landing in dire financial straits after following a stock tip from bombastic TV persona Lee Gates, fuming Kyle Budwell takes the lout hostage on live television and threatens to kill him unless he turns the stock price around before the closing bell.'},
#  'title': 'Money Monster',
#  'title_detail': {'base': 'http://dvd.netflix.com/Top100RSS',
#   'language': None,
#   'type': 'text/plain',
#   'value': 'Money Monster'}}

# %%
df
# Out:
#    guidislink                                                 id  \
# 0       False  https://dvd.netflix.com/Movie/Money-Monster/80...
# 1       False  https://dvd.netflix.com/Movie/Game-of-Thrones/...
# 2       False       https://dvd.netflix.com/Movie/Sully/80103102
# 3       False  https://dvd.netflix.com/Movie/Now-You-See-Me-2...
# 4       False  https://dvd.netflix.com/Movie/Ghostbusters/800...
# 5       False  https://dvd.netflix.com/Movie/Star-Trek-Beyond...
# 6       False  https://dvd.netflix.com/Movie/Captain-America-...
# 7       False  https://dvd.netflix.com/Movie/The-Legend-of-Ta...
# 8       False  https://dvd.netflix.com/Movie/The-Jungle-Book-...
# 9       False  https://dvd.netflix.com/Movie/Free-State-of-Jo...
# 10      False  https://dvd.netflix.com/Movie/The-Nice-Guys/80...
# 11      False  https://dvd.netflix.com/Movie/The-Magnificent-...
# 12      False  https://dvd.netflix.com/Movie/Jason-Bourne/800...
# 13      False  https://dvd.netflix.com/Movie/Hell-or-High-Wat...
# 14      False  https://dvd.netflix.com/Movie/Central-Intellig...
# 15      False  https://dvd.netflix.com/Movie/Batman-v-Superma...
# 16      False  https://dvd.netflix.com/Movie/X-Men-Apocalypse...
# 17      False  https://dvd.netflix.com/Movie/The-Huntsman-Win...
# 18      False  https://dvd.netflix.com/Movie/Independence-Day...
# 19      False  https://dvd.netflix.com/Movie/Whiskey-Tango-Fo...
# 20      False  https://dvd.netflix.com/Movie/Suicide-Squad/80...
# 21      False    https://dvd.netflix.com/Movie/Bad-Moms/80100906
# 22      False  https://dvd.netflix.com/Movie/Me-Before-You/80...
# 23      False  https://dvd.netflix.com/Movie/Deepwater-Horizo...
# 24      False  https://dvd.netflix.com/Movie/A-Hologram-for-t...
# 25      False  https://dvd.netflix.com/Movie/The-Infiltrator/...
# 26      False  https://dvd.netflix.com/Movie/The-Shallows/800...
# 3   [{'href': 'https://dvd.netflix.com/Movie/Now-Y...
# 4   [{'href': 'https://dvd.netflix.com/Movie/Ghost...
# 5   [{'href': 'https://dvd.netflix.com/Movie/Star-...
# 6   [{'href': 'https://dvd.netflix.com/Movie/Capta...
# 7   [{'href': 'https://dvd.netflix.com/Movie/The-L...
# 8   [{'href': 'https://dvd.netflix.com/Movie/The-J...
# 9   [{'href': 'https://dvd.netflix.com/Movie/Free-...
# 10  [{'href': 'https://dvd.netflix.com/Movie/The-N...
# 11  [{'href': 'https://dvd.netflix.com/Movie/The-M...
# 12  [{'href': 'https://dvd.netflix.com/Movie/Jason...
# 13  [{'href': 'https://dvd.netflix.com/Movie/Hell-...
# 14  [{'href': 'https://dvd.netflix.com/Movie/Centr...
# 15  [{'href': 'https://dvd.netflix.com/Movie/Batma...
# 16  [{'href': 'https://dvd.netflix.com/Movie/X-Men...
# 17  [{'href': 'https://dvd.netflix.com/Movie/The-H...
# 18  [{'href': 'https://dvd.netflix.com/Movie/Indep...
# 19  [{'href': 'https://dvd.netflix.com/Movie/Whisk...
# 20  [{'href': 'https://dvd.netflix.com/Movie/Suici...
# 21  [{'href': 'https://dvd.netflix.com/Movie/Bad-M...
# 22  [{'href': 'https://dvd.netflix.com/Movie/Me-Be...
# 23  [{'href': 'https://dvd.netflix.com/Movie/Deepw...
# 24  [{'href': 'https://dvd.netflix.com/Movie/A-Hol...
# 25  [{'href': 'https://dvd.netflix.com/Movie/The-I...
# 26  [{'href': 'https://dvd.netflix.com/Movie/The-S...
# 27  [{'href': 'https://dvd.netflix.com/Movie/The-B...
# 28  [{'href': 'https://dvd.netflix.com/Movie/Eye-i...
# 29  [{'href': 'https://dvd.netflix.com/Movie/Outla...
# ..                                                ...
# 70  [{'href': 'https://dvd.netflix.com/Movie/Cafe-...
# 71  [{'href': 'https://dvd.netflix.com/Movie/The-H...
# 72  [{'href': 'https://dvd.netflix.com/Movie/Mike-...
# 73  [{'href': 'https://dvd.netflix.com/Movie/The-B...
# 74  [{'href': 'https://dvd.netflix.com/Movie/Concu...
# 75  [{'href': 'https://dvd.netflix.com/Movie/Hacks...
# 76  [{'href': 'https://dvd.netflix.com/Movie/Keanu...
# 77  [{'href': 'https://dvd.netflix.com/Movie/Hunt-...
# 78  [{'href': 'https://dvd.netflix.com/Movie/Geniu...
# 79  [{'href': 'https://dvd.netflix.com/Movie/Wild-...
# 80  [{'href': 'https://dvd.netflix.com/Movie/Dark-...
# 81  [{'href': 'https://dvd.netflix.com/Movie/The-C...
# 82  [{'href': 'https://dvd.netflix.com/Movie/The-N...
# 83  [{'href': 'https://dvd.netflix.com/Movie/Brook...
# 84  [{'href': 'https://dvd.netflix.com/Movie/Midni...
# 85  [{'href': 'https://dvd.netflix.com/Movie/Hail-...
# 86  [{'href': 'https://dvd.netflix.com/Movie/Manch...
# 87  [{'href': 'https://dvd.netflix.com/Movie/Pete-...
# 88  [{'href': 'https://dvd.netflix.com/Movie/The-I...
# 89  [{'href': 'https://dvd.netflix.com/Movie/Star-...
# 90  [{'href': 'https://dvd.netflix.com/Movie/Eddie...
# 91  [{'href': 'https://dvd.netflix.com/Movie/Snowd...
# 92  [{'href': 'https://dvd.netflix.com/Movie/In-th...
# 93  [{'href': 'https://dvd.netflix.com/Movie/Alice...
# 94  [{'href': 'https://dvd.netflix.com/Movie/Zooto...
# 95  [{'href': 'https://dvd.netflix.com/Movie/Demol...
# 96  [{'href': 'https://dvd.netflix.com/Movie/God-s...
# 97  [{'href': 'https://dvd.netflix.com/Movie/The-G...
# 98  [{'href': 'https://dvd.netflix.com/Movie/Longm...
# 99  [{'href': 'https://dvd.netflix.com/Movie/The-A...
#
#                                               summary  \
# 0   <a href="https://dvd.netflix.com/Movie/Money-M...
# 1   <a href="https://dvd.netflix.com/Movie/Game-of...
# 2   <a href="https://dvd.netflix.com/Movie/Sully/8...
# 3   <a href="https://dvd.netflix.com/Movie/Now-You...
# 4   <a href="https://dvd.netflix.com/Movie/Ghostbu...
# 5   <a href="https://dvd.netflix.com/Movie/Star-Tr...
# 6   <a href="https://dvd.netflix.com/Movie/Captain...
# 7   <a href="https://dvd.netflix.com/Movie/The-Leg...
# 8   <a href="https://dvd.netflix.com/Movie/The-Jun...
# 9   <a href="https://dvd.netflix.com/Movie/Free-St...
# 10  <a href="https://dvd.netflix.com/Movie/The-Nic...
# 11  <a href="https://dvd.netflix.com/Movie/The-Mag...
# 12  <a href="https://dvd.netflix.com/Movie/Jason-B...
# 13  <a href="https://dvd.netflix.com/Movie/Hell-or...
# 14  <a href="https://dvd.netflix.com/Movie/Central...
# 15  <a href="https://dvd.netflix.com/Movie/Batman-...
# 16  <a href="https://dvd.netflix.com/Movie/X-Men-A...
# 17  <a href="https://dvd.netflix.com/Movie/The-Hun...
# 18  <a href="https://dvd.netflix.com/Movie/Indepen...
# 19  <a href="https://dvd.netflix.com/Movie/Whiskey...
# 20  <a href="https://dvd.netflix.com/Movie/Suicide...
# 21  <a href="https://dvd.netflix.com/Movie/Bad-Mom...
# 22  <a href="https://dvd.netflix.com/Movie/Me-Befo...
# 23  <a href="https://dvd.netflix.com/Movie/Deepwat...
# 24  <a href="https://dvd.netflix.com/Movie/A-Holog...
# 25  <a href="https://dvd.netflix.com/Movie/The-Inf...
# 26  <a href="https://dvd.netflix.com/Movie/The-Sha...
# 27  <a href="https://dvd.netflix.com/Movie/The-Bos...
# 28  <a href="https://dvd.netflix.com/Movie/Eye-in-...
# 29  <a href="https://dvd.netflix.com/Movie/Outland...
# ..                                                ...
# 70  <a href="https://dvd.netflix.com/Movie/Cafe-So...
# 71  <a href="https://dvd.netflix.com/Movie/The-Hat...
# 72  <a href="https://dvd.netflix.com/Movie/Mike-an...
# 73  <a href="https://dvd.netflix.com/Movie/The-BFG...
# 74  <a href="https://dvd.netflix.com/Movie/Concuss...
# 75  <a href="https://dvd.netflix.com/Movie/Hacksaw...
# 76  <a href="https://dvd.netflix.com/Movie/Keanu/8...
# 77  <a href="https://dvd.netflix.com/Movie/Hunt-fo...
# 78  <a href="https://dvd.netflix.com/Movie/Genius/...
# 79  <a href="https://dvd.netflix.com/Movie/Wild-Oa...
# 80  <a href="https://dvd.netflix.com/Movie/Dark-Ho...
# 81  <a href="https://dvd.netflix.com/Movie/The-Con...
# 82  <a href="https://dvd.netflix.com/Movie/The-Nig...
# 83  <a href="https://dvd.netflix.com/Movie/Brookly...
# 84  <a href="https://dvd.netflix.com/Movie/Midnigh...
# 85  <a href="https://dvd.netflix.com/Movie/Hail-Ca...
# 86  <a href="https://dvd.netflix.com/Movie/Manches...
# 87  <a href="https://dvd.netflix.com/Movie/Pete-s-...
# 88  <a href="https://dvd.netflix.com/Movie/The-Int...
# 89  <a href="https://dvd.netflix.com/Movie/Star-Wa...
# 90  <a href="https://dvd.netflix.com/Movie/Eddie-t...
# 91  <a href="https://dvd.netflix.com/Movie/Snowden...
# 92  <a href="https://dvd.netflix.com/Movie/In-the-...
# 93  <a href="https://dvd.netflix.com/Movie/Alice-T...
# 94  <a href="https://dvd.netflix.com/Movie/Zootopi...
# 95  <a href="https://dvd.netflix.com/Movie/Demolit...
# 96  <a href="https://dvd.netflix.com/Movie/God-s-N...
# 97  <a href="https://dvd.netflix.com/Movie/The-Goo...
# 98  <a href="https://dvd.netflix.com/Movie/Longmir...
# 99  <a href="https://dvd.netflix.com/Movie/The-Ang...
#
#                                        summary_detail  \
# 0   {'language': None, 'value': '<a href="https://...
# 1   {'language': None, 'value': '<a href="https://...
# 2   {'language': None, 'value': '<a href="https://...
# 3   {'language': None, 'value': '<a href="https://...
# 4   {'language': None, 'value': '<a href="https://...
# 5   {'language': None, 'value': '<a href="https://...
# 6   {'language': None, 'value': '<a href="https://...
# 7   {'language': None, 'value': '<a href="https://...
# 8   {'language': None, 'value': '<a href="https://...
# 9   {'language': None, 'value': '<a href="https://...
# 10  {'language': None, 'value': '<a href="https://...
# 11  {'language': None, 'value': '<a href="https://...
# 12  {'language': None, 'value': '<a href="https://...
# 13  {'language': None, 'value': '<a href="https://...
# 14  {'language': None, 'value': '<a href="https://...
# 15  {'language': None, 'value': '<a href="https://...
# 16  {'language': None, 'value': '<a href="https://...
# 17  {'language': None, 'value': '<a href="https://...
# 18  {'language': None, 'value': '<a href="https://...
# 19  {'language': None, 'value': '<a href="https://...
# 20  {'language': None, 'value': '<a href="https://...
# 21  {'language': None, 'value': '<a href="https://...
# 22  {'language': None, 'value': '<a href="https://...
# 23  {'language': None, 'value': '<a href="https://...
# 24  {'language': None, 'value': '<a href="https://...
# 25  {'language': None, 'value': '<a href="https://...
# 26  {'language': None, 'value': '<a href="https://...
# 27  {'language': None, 'value': '<a href="https://...
# 28  {'language': None, 'value': '<a href="https://...
# 29  {'language': None, 'value': '<a href="https://...
# ..                                                ...
# 70  {'language': None, 'value': '<a href="https://...
# 71  {'language': None, 'value': '<a href="https://...
# 72  {'language': None, 'value': '<a href="https://...
# 73  {'language': None, 'value': '<a href="https://...
# 74  {'language': None, 'value': '<a href="https://...
# 75  {'language': None, 'value': '<a href="https://...
# 76  {'language': None, 'value': '<a href="https://...
# 77  {'language': None, 'value': '<a href="https://...
# 78  {'language': None, 'value': '<a href="https://...
# 79  {'language': None, 'value': '<a href="https://...
# 80  {'language': None, 'value': '<a href="https://...
# 81  {'language': None, 'value': '<a href="https://...
# 82  {'language': None, 'value': '<a href="https://...
# 83  {'language': None, 'value': '<a href="https://...
# 84  {'language': None, 'value': '<a href="https://...
# 85  {'language': None, 'value': '<a href="https://...
# 86  {'language': None, 'value': '<a href="https://...
# 87  {'language': None, 'value': '<a href="https://...
# 88  {'language': None, 'value': '<a href="https://...
# 89  {'language': None, 'value': '<a href="https://...
# 90  {'language': None, 'value': '<a href="https://...
# 91  {'language': None, 'value': '<a href="https://...
# 92  {'language': None, 'value': '<a href="https://...
# 93  {'language': None, 'value': '<a href="https://...
# 94  {'language': None, 'value': '<a href="https://...
# 95  {'language': None, 'value': '<a href="https://...
# 96  {'language': None, 'value': '<a href="https://...
# 97  {'language': None, 'value': '<a href="https://...
# 98  {'language': None, 'value': '<a href="https://...
# 99  {'language': None, 'value': '<a href="https://...
#
#                                         title  \
# 0                               Money Monster
# 1                             Game of Thrones
# 2                                       Sully
# 3                            Now You See Me 2
# 4                                Ghostbusters
# 5                            Star Trek Beyond
# 6                  Captain America: Civil War
# 7                        The Legend of Tarzan
# 8                      The Jungle Book (2016)
# 9                         Free State of Jones
# 10                              The Nice Guys
# 11                      The Magnificent Seven
# 12                               Jason Bourne
# 13                         Hell or High Water
# 14                       Central Intelligence
# 15         Batman v Superman: Dawn of Justice
# 16                          X-Men: Apocalypse
# 17                 The Huntsman: Winter's War
# 18               Independence Day: Resurgence
# 19                      Whiskey Tango Foxtrot
# 20                              Suicide Squad
# 21                                   Bad Moms
# 22                              Me Before You
# 23                          Deepwater Horizon
# 24                    A Hologram for the King
# 25                            The Infiltrator
# 26                               The Shallows
# 27                                   The Boss
# 28                             Eye in the Sky
# 29                                  Outlander
# ..                                        ...
# 70                               Café Society
# 71                          The Hateful Eight
# 72           Mike and Dave Need Wedding Dates
# 73                                    The BFG
# 74                                 Concussion
# 75                              Hacksaw Ridge
# 76                                      Keanu
# 77                  Hunt for the Wilderpeople
# 78                                     Genius
# 79                                  Wild Oats
# 80                                 Dark Horse
# 81                            The Conjuring 2
# 82                          The Night Manager
# 83                                   Brooklyn
# 84                           Midnight Special
# 85                              Hail, Caesar!
# 86                      Manchester by the Sea
# 87                              Pete's Dragon
# 88                                 The Intern
# 89  Star Wars: Episode VII: The Force Awakens
# 90                            Eddie the Eagle
# 91                                    Snowden
# 92                    In the Heart of the Sea
# 93            Alice Through the Looking Glass
# 94                                   Zootopia
# 95                                 Demolition
# 96                           God's Not Dead 2
# 97                              The Good Wife
# 98                                   Longmire
# 99                      The Angry Birds Movie
#
#                                          title_detail
# 0   {'language': None, 'value': 'Money Monster', '...
# 1   {'language': None, 'value': 'Game of Thrones',...
# 2   {'language': None, 'value': 'Sully', 'type': '...
# 3   {'language': None, 'value': 'Now You See Me 2'...
# 4   {'language': None, 'value': 'Ghostbusters', 't...
# 5   {'language': None, 'value': 'Star Trek Beyond'...
# 6   {'language': None, 'value': 'Captain America: ...
# 7   {'language': None, 'value': 'The Legend of Tar...
# 8   {'language': None, 'value': 'The Jungle Book (...
# 9   {'language': None, 'value': 'Free State of Jon...
# 10  {'language': None, 'value': 'The Nice Guys', '...
# 11  {'language': None, 'value': 'The Magnificent S...
# 12  {'language': None, 'value': 'Jason Bourne', 't...
# 13  {'language': None, 'value': 'Hell or High Wate...
# 14  {'language': None, 'value': 'Central Intellige...
# 15  {'language': None, 'value': 'Batman v Superman...
# 16  {'language': None, 'value': 'X-Men: Apocalypse...
# 17  {'language': None, 'value': 'The Huntsman: Win...
# 18  {'language': None, 'value': 'Independence Day:...
# 19  {'language': None, 'value': 'Whiskey Tango Fox...
# 20  {'language': None, 'value': 'Suicide Squad', '...
# 21  {'language': None, 'value': 'Bad Moms', 'type'...
# 22  {'language': None, 'value': 'Me Before You', '...
# 23  {'language': None, 'value': 'Deepwater Horizon...
# 24  {'language': None, 'value': 'A Hologram for th...
# 25  {'language': None, 'value': 'The Infiltrator',...
# 26  {'language': None, 'value': 'The Shallows', 't...
# 27  {'language': None, 'value': 'The Boss', 'type'...
# 28  {'language': None, 'value': 'Eye in the Sky', ...
# 29  {'language': None, 'value': 'Outlander', 'type...
# ..                                                ...
# 70  {'language': None, 'value': 'Café Society', 't...
# 71  {'language': None, 'value': 'The Hateful Eight...
# 72  {'language': None, 'value': 'Mike and Dave Nee...
# 73  {'language': None, 'value': 'The BFG', 'type':...
# 74  {'language': None, 'value': 'Concussion', 'typ...
# 75  {'language': None, 'value': 'Hacksaw Ridge', '...
# 76  {'language': None, 'value': 'Keanu', 'type': '...
# 77  {'language': None, 'value': 'Hunt for the Wild...
# 78  {'language': None, 'value': 'Genius', 'type': ...
# 79  {'language': None, 'value': 'Wild Oats', 'type...
# 80  {'language': None, 'value': 'Dark Horse', 'typ...
# 81  {'language': None, 'value': 'The Conjuring 2',...
# 82  {'language': None, 'value': 'The Night Manager...
# 83  {'language': None, 'value': 'Brooklyn', 'type'...
# 84  {'language': None, 'value': 'Midnight Special'...
# 85  {'language': None, 'value': 'Hail, Caesar!', '...
# 86  {'language': None, 'value': 'Manchester by the...
# 87  {'language': None, 'value': 'Pete's Dragon', '...
# 88  {'language': None, 'value': 'The Intern', 'typ...
# 89  {'language': None, 'value': 'Star Wars: Episod...
# 90  {'language': None, 'value': 'Eddie the Eagle',...
# 91  {'language': None, 'value': 'Snowden', 'type':...
# 92  {'language': None, 'value': 'In the Heart of t...
# 93  {'language': None, 'value': 'Alice Through the...
# 94  {'language': None, 'value': 'Zootopia', 'type'...
# 95  {'language': None, 'value': 'Demolition', 'typ...
# 96  {'language': None, 'value': 'God's Not Dead 2'...
# 97  {'language': None, 'value': 'The Good Wife', '...
# 98  {'language': None, 'value': 'Longmire', 'type'...
# 99  {'language': None, 'value': 'The Angry Birds M...
#
# [100 rows x 8 columns]

# %%
df.summary[0]
# Out:
# '<a href="https://dvd.netflix.com/Movie/Money-Monster/80084089"><img src="//secure.netflix.com/us/boxshots/small/80084089.jpg"/></a><br>Landing in dire financial straits after following a stock tip from bombastic TV persona Lee Gates, fuming Kyle Budwell takes the lout hostage on live television and threatens to kill him unless he turns the stock price around before the closing bell.'
